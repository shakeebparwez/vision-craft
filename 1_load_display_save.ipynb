# %%
import numpy as np
import cv2 # opencv library

# %%
img = cv2.imread('./images/car_001.jpg') # bgr , # 8 bit

# %%
print(img) # 3d (row, col, channel)
# Out:
# [[[120 115 106]
#   [ 67  62  53]
#   [ 63  57  50]
#   ...
#   [151 137 125]
#   [ 98  92  85]
#   [ 59  56  52]]
#
#  [[110 105  96]
#   [ 61  56  47]
#   [ 67  61  54]
#   ...
#   [177 165 153]
#   [117 111 106]
#   [ 84  81  77]]
#
#  [[106  98  91]
#   [ 66  58  51]
#   [ 73  65  58]
#   ...
#   [150 138 126]
#   [ 82  76  71]
#   [ 58  56  55]]
#
#  ...
#
#  [[  6  17  25]
#   [ 10  21  29]
#   [  1  13  19]
#   ...
#   [123 126 124]
#   [127 128 126]
#   [131 132 130]]
#
#  [[  5  14  23]
#   [  0   0   7]
#   [  0  10  17]
#   ...
#   [141 146 144]
#   [146 151 149]
#   [149 154 152]]
#
#  [[  0   8  15]
#   [ 17  25  32]
#   [ 29  37  44]
#   ...
#   [143 149 148]
#   [141 147 146]
#   [141 147 146]]]

# %%
img.max()
# Out:
# 255

# %%
img.min()
# Out:
# 0

# %%
img.shape
# Out:
# (423, 678, 3)

# %%
img1 = cv2.imread('./images/asdfasdfa.jpg')

# %%
type(img1)
# Out:
# NoneType

# %% [markdown]
# # Display

# %%
cv2.imshow('orignal image',img)
cv2.waitKey(10000) # this command will display the window for n milliseconds 
cv2.destroyAllWindows()

# %%
cv2.imshow('orignal image',img)
cv2.waitKey(0) # this command display the window until you press x or any keybaord key
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt

# %%
# img BGR
plt.imshow(img[:,:,[2,1,0]]) # assume that image is in RGB format
plt.show()

# %% [markdown]
# # Save Image

# %%
cv2.imwrite('./images/save.png',img)
# Out:
# True

# %% [markdown]
# ---
